# %%
from EvalGenome import *


import multiprocessing
import os
import pickle

# import cart_pole
import neat
import visualize



  

runs_per_net = 2
simulation_seconds = 1000

def run():

    local_dir = os.getcwd()  # Get the current working directory
    config_path = os.path.join(local_dir, 'config')
    config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                 neat.DefaultSpeciesSet, neat.DefaultStagnation,
                 config_path)
    
    pop = neat.Population(config)
    stats = neat.StatisticsReporter()
    pop.add_reporter(stats)
    pop.add_reporter(neat.StdOutReporter(True))

    pe = neat.ParallelEvaluator(multiprocessing.cpu_count(), eval_genome)
    winner = pop.run(pe.evaluate)

    # Save the winner.
    with open('winner-feedforward', 'wb') as f:
        pickle.dump(winner, f)

    return winner, stats
# Out:
# imported eval_genome
# Imported initialized Variables
# imported Simulation
# imported Neural Network module
# imported Observation
# imported Agent module
# Imported environ
# imported evolution module

# %%
bestGene, stats = run()
# Out:
#  ****** Running generation 0 ******
#
# Population's average fitness: 0.05417 stdev: 0.03931
# Best fitness: 0.12500 - size: (8, 100) - species 1 - id 5
# Average adjusted fitness: 0.054
# Mean genetic distance 1.813, standard deviation 0.672
# Population of 6 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0     6      0.1    0.054     0
# Total extinctions: 0
# Generation time: 2.209 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: 0.05000 stdev: 0.03819
# Best fitness: 0.10000 - size: (8, 100) - species 1 - id 5
# Average adjusted fitness: 0.050
# Mean genetic distance 1.668, standard deviation 0.501
# Population of 6 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1     6      0.1    0.050     1
# Total extinctions: 0
# Generation time: 1.715 sec (1.962 average)
#
#  ****** Running generation 2 ******
# Process SpawnPoolWorker-3:
# Process SpawnPoolWorker-1:
# Process SpawnPoolWorker-7:
# Process SpawnPoolWorker-4:
# Process SpawnPoolWorker-8:
# Process SpawnPoolWorker-2:
# Process SpawnPoolWorker-5:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/christopherharding/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/christopherharding/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/christopherharding/opt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/christopherharding/opt/anaconda3/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/Users/christopherharding/opt/anaconda3/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/Users/christopherharding/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/christopherharding/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/christopherharding/opt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/christopherharding/opt/anaconda3/lib/python3.11/multiprocessing/queues.py", line 365, in get
#     res = self._reader.recv_bytes()
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/opt/anaconda3/lib/python3.11/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/opt/anaconda3/lib/python3.11/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/Users/christopherharding/opt/anaconda3/lib/python3.11/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/christopherharding/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/christopherharding/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/christopherharding/opt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/EvalGenome.py", line 11, in eval_genome
#     fitness = RunSim(genome)
#               ^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/Simulation.py", line 43, in RunSim
#     livingAgents, environment, killcount = simCycle(steps_per_cycle, agents, environment, barrierMask, distToBarrier, survivalMask,environment_pop_density, killing)
#                                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/Evolution.py", line 41, in simCycle
#     operateAll(agents, barrierMask, distToBarrier, environment_pop_density,  killing, survivalMask)
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/AgentModule.py", line 159, in operateAll
#     pts = agent.operate(agents, barrierMask,distToBarrier, environment_pop_density, killing, survivalMask)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/AgentModule.py", line 98, in operate
#     movement, killForward, plotpoints = self.agentBrain.think(self.angle, self.angularVelocity,self.xCoord, self.yCoord, barrierMask, killing, environment_pop_density, survivalMask)
#                                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/NeuralNetwork.py", line 91, in think
#     plotpoints = self.sense(theta, omega, xCoord, yCoord,killing, environment_pop_density, barrierMask, survivalMask)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neu
# imported eval_genome
# Imported initialized Variables
# imported Simulation
# imported Neural Network module
# imported Observation
# imported Agent module
# Imported environ
# imported evolution module
# imported eval_genome
# Imported initialized Variables
# imported Simulation
# imported Neural Network module
# imported Observation
# imported Agent module
# Imported environ
# imported evolution module
# imported eval_genome
# Imported initialized Variables
# imported Simulation
# imported Neural Network module
# imported Observation
# imported Agent module
# Imported environ
# imported evolution module
# imported eval_genome
# Imported initialized Variables
# imported Simulation
# imported Neural Network module
# imported Observation
# imported Agent module
# Imported environ
# imported evolution module
# imported eval_genome
# Imported initialized Variables
# imported Simulation
# imported Neural Network module
# imported Observation
# imported Agent module
# Imported environ
# imported evolution module
# imported eval_genome
# Imported initialized Variables
# imported Simulation
# imported Neural Network module
# imported Observation
# imported Agent module
# Imported environ
# imported evolution module
# imported eval_genome
# Imported initialized Variables
# imported Simulation
# imported Neural Network module
# imported Observation
# imported Agent module
# Imported environ
# imported evolution module
# imported eval_genome
# Imported initialized Variables
# imported Simulation
# imported Neural Network module
# imported Observation
# imported Agent module
# Imported environ
# imported evolution module
# roevolution-NEAT_brains/angular_changes/Neuroevolution/NeuralNetwork.py", line 128, in sense
#     results = rayDist(xCoord, yCoord, theta, angle, environment_pop_density, barrierMask, survivalMask)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/NodeFunctions.py", line 148, in rayDist
#     return calculateRayIntersection(xCoord, yCoord, start_angle, theta, obstructions, survivalMask)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/NodeFunctions.py", line 185, in calculateRayIntersection
#     while True and distance < vision_distance:
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/Users/christopherharding/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/christopherharding/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/christopherharding/opt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/EvalGenome.py", line 11, in eval_genome
#     fitness = RunSim(genome)
#               ^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/Simulation.py", line 43, in RunSim
#     livingAgents, environment, killcount = simCycle(steps_per_cycle, agents, environment, barrierMask, distToBarrier, survivalMask,environment_pop_density, killing)
#                                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/Evolution.py", line 41, in simCycle
#     operateAll(agents, barrierMask, distToBarrier, environment_pop_density,  killing, survivalMask)
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/AgentModule.py", line 159, in operateAll
#     pts = agent.operate(agents, barrierMask,distToBarrier, environment_pop_density, killing, survivalMask)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/AgentModule.py", line 98, in operate
#     movement, killForward, plotpoints = self.agentBrain.think(self.angle, self.angularVelocity,self.xCoord, self.yCoord, barrierMask, killing, environment_pop_density, survivalMask)
#                                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/NeuralNetwork.py", line 91, in think
#     plotpoints = self.sense(theta, omega, xCoord, yCoord,killing, environment_pop_density, barrierMask, survivalMask)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/NeuralNetwork.py", line 128, in sense
#     results = rayDist(xCoord, yCoord, theta, angle, environment_pop_density, barrierMask, survivalMask)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/NodeFunctions.py", line 148, in rayDist
#     return calculateRayIntersection(xCoord, yCoord, start_angle, theta, obstructions, survivalMask)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/NodeFunctions.py", line 188, in calculateRayIntersection
#     next_y = int(y + distance * dy + facingCoord_y)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/christopherharding/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/christopherharding/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/christopherharding/opt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/EvalGenome.py", line 11, in eval_genome
#     fitness = RunSim(genome)
#               ^^^^^^^^^^^^^^
#   File "/Users/christopherharding/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/Simulation.py", line 43, in RunSim
#     livingAgents, environment, killcount = simCycle(steps_per_cycle, agents, environment, barrierMask, distToBarrier, survivalMask,environment_pop_density, killing)
#                                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/Evolution.py", line 41, in simCycle
#     operateAll(agents, barrierMask, distToBarrier, environment_pop_density,  killing, survivalMask)
#   File "/Users/christopherharding/opt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/EvalGenome.py", line 11, in eval_genome
#     fitness = RunSim(genome)
#               ^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/AgentModule.py", line 159, in operateAll
#     pts = agent.operate(agents, barrierMask,distToBarrier, environment_pop_density, killing, survivalMask)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/Simulation.py", line 43, in RunSim
#     livingAgents, environment, killcount = simCycle(steps_per_cycle, agents, environment, barrierMask, distToBarrier, survivalMask,environment_pop_density, killing)
#                                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/AgentModule.py", line 98, in operate
#     movement, killForward, plotpoints = self.agentBrain.think(self.angle, self.angularVelocity,self.xCoord, self.yCoord, barrierMask, killing, environment_pop_density, survivalMask)
#                                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/Evolution.py", line 41, in simCycle
#     operateAll(agents, barrierMask, distToBarrier, environment_pop_density,  killing, survivalMask)
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/NeuralNetwork.py", line 91, in think
#     plotpoints = self.sense(theta, omega, xCoord, yCoord,killing, environment_pop_density, barrierMask, survivalMask)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/NeuralNetwork.py", line 128, in sense
#     results = rayDist(xCoord, yCoord, theta, angle, environment_pop_density, barrierMask, survivalMask)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/AgentModule.py", line 159, in operateAll
#     pts = agent.operate(agents, barrierMask,distToBarrier, environment_pop_density, killing, survivalMask)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/NodeFunctions.py", line 148, in rayDist
#     return calculateRayIntersection(xCoord, yCoord, start_angle, theta, obstructions, survivalMask)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/NodeFunctions.py", line 185, in calculateRayIntersection
#     while True and distance < vision_distance:
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/AgentModule.py", line 98, in operate
#     movement, killForward, plotpoints = self.agentBrain.think(self.angle, self.angularVelocity,self.xCoord, self.yCoord, barrierMask, killing, environment_pop_density, survivalMask)
#                                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/NeuralNetwork.py", line 91, in think
#     plotpoints = self.sense(theta, omega, xCoord, yCoord,killing, environment_pop_density, barrierMask, survivalMask)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/NeuralNetwork.py", line 128, in sense
#     results = rayDist(xCoord, yCoord, theta, angle, environment_pop_density, barrierMask, survivalMask)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/NodeFunctions.py", line 148, in rayDist
#     return calculateRayIntersection(xCoord, yCoord, start_angle, theta, obstructions, survivalMask)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/NodeFunctions.py", line 187, in calculateRayIntersection
#     next_x = int(x + distance * dx + facingCoord_x)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Process SpawnPoolWorker-6:
#   File "/Users/christopherharding/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/christopherharding/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/christopherharding/opt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/EvalGenome.py", line 11, in eval_genome
#     fitness = RunSim(genome)
#               ^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/Simulation.py", line 43, in RunSim
#     livingAgents, environment, killcount = simCycle(steps_per_cycle, agents, environment, barrierMask, distToBarrier, survivalMask,environment_pop_density, killing)
#                                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/Evolution.py", line 41, in simCycle
#     operateAll(agents, barrierMask, distToBarrier, environment_pop_density,  killing, survivalMask)
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/AgentModule.py", line 159, in operateAll
#     pts = agent.operate(agents, barrierMask,distToBarrier, environment_pop_density, killing, survivalMask)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/AgentModule.py", line 98, in operate
#     movement, killForward, plotpoints = self.agentBrain.think(self.angle, self.angularVelocity,self.xCoord, self.yCoord, barrierMask, killing, environment_pop_density, survivalMask)
#                                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/NeuralNetwork.py", line 91, in think
#     plotpoints = self.sense(theta, omega, xCoord, yCoord,killing, environment_pop_density, barrierMask, survivalMask)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/NeuralNetwork.py", line 126, in sense
#     angles = np.linspace(-angleMax, angleMax, numRays)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/opt/anaconda3/lib/python3.11/site-packages/numpy/core/function_base.py", line 140, in linspace
#     y = _nx.arange(0, num, dtype=dt).reshape((-1,) + (1,) * ndim(delta))
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/christopherharding/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/christopherharding/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/christopherharding/opt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/EvalGenome.py", line 11, in eval_genome
#     fitness = RunSim(genome)
#               ^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/Simulation.py", line 28, in RunSim
#     distToBarrier = getBarrierMaskDist(barrierMask)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/Desktop/Spring24/530/Neuroevolution-main/Neuroevolution-NEAT_brains/angular_changes/Neuroevolution/Environment.py", line 25, in getBarrierMaskDist
#     distance_transform = distance_transform_bf(barrierMask)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/christopherharding/opt/anaconda3/lib/python3.11/site-packages/scipy/ndimage/_morphology.py", line 2072, in distance_transform_bf
#     _nd_image.distance_transform_bf(tmp1, metric, sampling, dt, ft)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 bestGene, stats = run()
#
# Cell In[1], line 33, in run()
#      30 pop.add_reporter(neat.StdOutReporter(True))
#      32 pe = neat.ParallelEvaluator(multiprocessing.cpu_count(), eval_genome)
# ---> 33 winner = pop.run(pe.evaluate)
#      35 # Save the winner.
#      36 # with open('winner-feedforward', 'wb') as f:
#      37 #     pickle.dump(winner, f)
#      39 return winner, stats
#
# File ~/opt/anaconda3/lib/python3.11/site-packages/neat/population.py:89, in Population.run(self, fitness_function, n)
#      86 self.reporters.start_generation(self.generation)
#      88 # Evaluate all genomes using the user-provided function.
# ---> 89 fitness_function(list(iteritems(self.population)), self.config)
#      91 # Gather and report statistics.
#      92 best = None
#
# File ~/opt/anaconda3/lib/python3.11/site-packages/neat/parallel.py:30, in ParallelEvaluator.evaluate(self, genomes, config)
#      28 # assign the fitness back to each genome
#      29 for job, (ignored_genome_id, genome) in zip(jobs, genomes):
# ---> 30     genome.fitness = job.get(timeout=self.timeout)
#
# File ~/opt/anaconda3/lib/python3.11/multiprocessing/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File ~/opt/anaconda3/lib/python3.11/multiprocessing/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File ~/opt/anaconda3/lib/python3.11/threading.py:629, in Event.wait(self, timeout)
#     627 signaled = self._flag
#     628 if not signaled:
# --> 629     signaled = self._cond.wait(timeout)
#     630 return signaled
#
# File ~/opt/anaconda3/lib/python3.11/threading.py:327, in Condition.wait(self, timeout)
#     325 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     326     if timeout is None:
# --> 327         waiter.acquire()
#     328         gotit = True
#     329     else:
#
# KeyboardInterrupt:

# %%
draw_net(config, bestGene, view=True)

# %%
# %matplotlib inline

plot_stats(stats, ylog=True, view=True, filename="feedforward-fitness.svg")

# %%
plot_species(stats, view=True, filename="feedforward-speciation.svg")

# %%
from NeuralNetwork import * 
from Observation import *
from AgentModule import *
from InitializationVariables import *
from Environment import *
from Evolution import *

# %%
# %matplotlib inline

environment, agents, environment_pop_density = initialize()

agents = initializeAgents(agent_count, agents, bestGene)

barrierMask = getBarrierMask()
distToBarrier = getBarrierMaskDist(barrierMask)
survivalMask = getSurvivalMask()

survivalMask[0:-1,0:-1] = 0
survivalMask[0 :environment_xSize//3, 0 :environment_xSize//3   ]= 1

livingAgents, environment, killCount = runCycle(steps_per_cycle, agents, environment, barrierMask, distToBarrier, survivalMask, environment_pop_density, False)

# %% [markdown]
# ###
